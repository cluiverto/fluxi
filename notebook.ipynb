# %%
import fluxi

# Użycie wrappera
pipe = fluxi.Generate()
pipe.generate_image("Polish old town, lego style")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# c:\Users\mikoo\miniconda3\envs\primo\Lib\site-packages\transformers\models\clip\modeling_clip.py:480: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
#   0%|          | 0/4 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1360x768>

# %%
flux_inference
